# %%
# Data Cleaning and Preprocessing

#This notebook prepares GTFS static and real-time data for analysis.
#It computes arrival delays and generates a cleaned dataset for further visualization and analysis.

# %%
# !pip install geopandas openpyxl
# !pip install gtfs-realtime-bindings
# Out:
# Requirement already satisfied: geopandas in /opt/anaconda3/lib/python3.13/site-packages (1.1.3)
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: et_xmlfile in /opt/anaconda3/lib/python3.13/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Requirement already satisfied: gtfs-realtime-bindings in /opt/anaconda3/lib/python3.13/site-packages (2.0.0)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from gtfs-realtime-bindings) (5.29.3)

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from datetime import datetime
import requests
from google.transit import gtfs_realtime_pb2

# %%
#Source: https://data.vta.org/datasets/VTA::vta-stops-and-routes-october-2025/explore?layer=1
routes_gdf = gpd.read_file('../02-data/raw/Routes_October_2025.geojson')
routes_gdf = routes_gdf.to_crs("EPSG:2227")

selected_routes = ['22', '522', '23', '523', '25', '60']

#select routes 22, 522, 23, 523, 25, and 60
selected_routes_gdf = routes_gdf[routes_gdf['lineabbr'].isin(selected_routes)]
selected_routes_gdf = selected_routes_gdf.rename(columns={
    'lineid' : 'route_id',
    'lineabbr' : 'route_name',
    'linename' : 'route_desc',
    'SHAPE__Length' : 'route_length',
    'objectid' : 'object_id'
    })

selected_routes_gdf
# Out:
#     route_id route_name                         route_desc  category  \
# 2      23875         22              PALO ALTO - EASTRIDGE  Frequent
# 3      23876         23        DE ANZA COL - ALUM ROCK STN  Frequent
# 4      23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 20     23904         60     WINCHESTER STN - MILPITAS BART  Frequent
# 54     23896        522              PALO ALTO - EASTRIDGE     Rapid
# 55     23897        523   SAN JOSE STATE - LOCKHEED MARTIN     Rapid
#
#      route_length  object_id  \
# 2   242559.907697          3
# 3   120202.952188          4
# 4   140850.289491          5
# 20  151256.059019         21
# 54  253522.042435         55
# 55  162676.690292         56
#
#                                              geometry
# 2   MULTILINESTRING ((6078119.778 1988262.118, 607...
# 3   MULTILINESTRING ((6158969.916 1948773.278, 615...
# 4   MULTILINESTRING ((6159010.362 1938537.341, 615...
# 20  MULTILINESTRING ((6140271.175 1927485.171, 614...
# 54  MULTILINESTRING ((6078119.778 1988262.118, 607...
# 55  MULTILINESTRING ((6117717.98 1975678.638, 6117...

# %%
selected_routes_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 6 entries, 2 to 55
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   route_id      6 non-null      int32
#  1   route_name    6 non-null      object
#  2   route_desc    6 non-null      object
#  3   category      6 non-null      object
#  4   route_length  6 non-null      float64
#  5   object_id     6 non-null      int32
#  6   geometry      6 non-null      geometry
# dtypes: float64(1), geometry(1), int32(2), object(3)
# memory usage: 336.0+ bytes

# %%
selected_routes_gdf.plot()
# Out:
# <Axes: >

# %%
#Source: https://data.vta.org/datasets/VTA::vta-stops-and-routes-october-2025/about?layer=0
stations_df = pd.read_csv("../02-data/raw/Bus_LightRail_Stops.csv")
stations_df
# Out:
#                  X             Y      routes  linedirid   rtid  \
# 0     6.144100e+06  1.954226e+06          22     238750  60001
# 1     6.146822e+06  1.959781e+06      60, 60     239040  60008
# 2     6.148115e+06  1.958315e+06          60     239041  60011
# 3     6.150233e+06  1.960219e+06          60     239041  60014
# 4     6.141651e+06  1.954992e+06  22, 59, 60     238750  60020
# ...            ...           ...         ...        ...    ...
# 3245  6.140506e+06  1.930527e+06          26     238821  66063
# 3246  6.157411e+06  1.941970e+06         201     238710  66066
# 3247  6.146206e+06  1.935440e+06         202     238720  66067
# 3248  6.190774e+06  1.935478e+06      31, 39     238870  66068
# 3249  6.148984e+06  1.978946e+06          47     238921  66069
#
#                            stopname  objectid
# 0        Santa Clara Transit Center         1
# 1       San Jose Airport Terminal A         2
# 2       San Jose Airport Terminal B         3
# 3       1st & Metro @ Metro Station         4
# 4             El Camino & Lafayette         5
# ...                             ...       ...
# 3245             Civic Center & 3rd      3246
# 3246    Virginia & Virginia Station      3247
# 3247  Stokes & Southwest Expressway      3248
# 3248            San Felipe & Bowery      3249
# 3249              Bellew & McCarthy      3250
#
# [3250 rows x 7 columns]

# %%
#Source: https://data.vta.org/pages/f2ebbac0b3a84c5e958ca45a4676f282
ridership_df = pd.read_excel("../02-data/raw/October_2025_Ridership_by_Stop.xlsx")
ridership_df = ridership_df.rename(columns={"Stop_ID_Num": "rtid"})
ridership_df
# Out:
#        rtid SERVICE_PERIOD              MAIN_CROSS_STREET ROUTES_SERVED  \
# 0     60001        Weekday     SANTA CLARA TRANSIT CENTER            22
# 1     60008        Weekday  SAN JOSE AIRPORT - TERMINAL A            60
# 2     60011        Weekday  SAN JOSE AIRPORT - TERMINAL B            60
# 3     60014        Weekday                    1ST + METRO            60
# 4     60020        Weekday          EL CAMINO + LAFAYETTE    22, 59, 60
# ...     ...            ...                            ...           ...
# 3113  66063        Weekday             CIVIC CENTER + 3RD            26
# 3114  66066        Weekday    VIRGINIA + VIRGINIA STATION           201
# 3115  66067        Weekday       STOKES + SOUTHWEST EXPWY           202
# 3116  66068        Weekday            SAN FELIPE + BOWERY        31, 39
# 3117  66069        Weekday              Bellew + McCarthy            44
#
#       AVG_BOARDINGS  AVG_ALIGHTINGS  AVG_ACTIVITY
# 0        152.880022      110.852250    263.732272
# 1        106.410278       97.183657    203.593936
# 2        101.895229       69.917892    171.813122
# 3         99.060686       57.995466    157.056152
# 4         40.890986       57.438087     98.329073
# ...             ...             ...           ...
# 3113       3.281537       14.682573     17.964110
# 3114       0.333333        0.000000      0.333333
# 3115       0.000000        0.357143      0.357143
# 3116       1.279642        0.336508      1.616150
# 3117       5.926389        7.870670     13.797059
#
# [3118 rows x 7 columns]

# %%
station_ridership_df = pd.merge(stations_df, ridership_df, on='rtid', how='left')
station_ridership_df
# Out:
#                  X             Y      routes  linedirid   rtid  \
# 0     6.144100e+06  1.954226e+06          22     238750  60001
# 1     6.146822e+06  1.959781e+06      60, 60     239040  60008
# 2     6.148115e+06  1.958315e+06          60     239041  60011
# 3     6.150233e+06  1.960219e+06          60     239041  60014
# 4     6.141651e+06  1.954992e+06  22, 59, 60     238750  60020
# ...            ...           ...         ...        ...    ...
# 3245  6.140506e+06  1.930527e+06          26     238821  66063
# 3246  6.157411e+06  1.941970e+06         201     238710  66066
# 3247  6.146206e+06  1.935440e+06         202     238720  66067
# 3248  6.190774e+06  1.935478e+06      31, 39     238870  66068
# 3249  6.148984e+06  1.978946e+06          47     238921  66069
#
#                            stopname  objectid SERVICE_PERIOD  \
# 0        Santa Clara Transit Center         1        Weekday
# 1       San Jose Airport Terminal A         2        Weekday
# 2       San Jose Airport Terminal B         3        Weekday
# 3       1st & Metro @ Metro Station         4        Weekday
# 4             El Camino & Lafayette         5        Weekday
# ...                             ...       ...            ...
# 3245             Civic Center & 3rd      3246        Weekday
# 3246    Virginia & Virginia Station      3247        Weekday
# 3247  Stokes & Southwest Expressway      3248        Weekday
# 3248            San Felipe & Bowery      3249        Weekday
# 3249              Bellew & McCarthy      3250        Weekday
#
#                   MAIN_CROSS_STREET ROUTES_SERVED  AVG_BOARDINGS  \
# 0        SANTA CLARA TRANSIT CENTER            22     152.880022
# 1     SAN JOSE AIRPORT - TERMINAL A            60     106.410278
# 2     SAN JOSE AIRPORT - TERMINAL B            60     101.895229
# 3                       1ST + METRO            60      99.060686
# 4             EL CAMINO + LAFAYETTE    22, 59, 60      40.890986
# ...                             ...           ...            ...
# 3245             CIVIC CENTER + 3RD            26       3.281537
# 3246    VIRGINIA + VIRGINIA STATION           201       0.333333
# 3247       STOKES + SOUTHWEST EXPWY           202       0.000000
# 3248            SAN FELIPE + BOWERY        31, 39       1.279642
# 3249              Bellew + McCarthy            44       5.926389
#
#       AVG_ALIGHTINGS  AVG_ACTIVITY
# 0         110.852250    263.732272
# 1          97.183657    203.593936
# 2          69.917892    171.813122
# 3          57.995466    157.056152
# 4          57.438087     98.329073
# ...              ...           ...
# 3245       14.682573     17.964110
# 3246        0.000000      0.333333
# 3247        0.357143      0.357143
# 3248        0.336508      1.616150
# 3249        7.870670     13.797059
#
# [3250 rows x 13 columns]

# %%
#set routes data type to str only and if 2 routes share a station, give each its own row for easier filtering later
station_ridership_df["routes"] = station_ridership_df["routes"].str.split(", ")
station_ridership_df = station_ridership_df.explode("routes")
station_ridership_df = station_ridership_df.drop_duplicates()

station_ridership_gdf_geometry = [Point(xy) for xy in zip(station_ridership_df["X"], station_ridership_df["Y"])]

station_ridership_gdf = gpd.GeoDataFrame(station_ridership_df, geometry=station_ridership_gdf_geometry, crs="EPSG:2227")
station_ridership_gdf
# Out:
#                  X             Y routes  linedirid   rtid  \
# 0     6.144100e+06  1.954226e+06     22     238750  60001
# 1     6.146822e+06  1.959781e+06     60     239040  60008
# 2     6.148115e+06  1.958315e+06     60     239041  60011
# 3     6.150233e+06  1.960219e+06     60     239041  60014
# 4     6.141651e+06  1.954992e+06     22     238750  60020
# ...            ...           ...    ...        ...    ...
# 3246  6.157411e+06  1.941970e+06    201     238710  66066
# 3247  6.146206e+06  1.935440e+06    202     238720  66067
# 3248  6.190774e+06  1.935478e+06     31     238870  66068
# 3248  6.190774e+06  1.935478e+06     39     238870  66068
# 3249  6.148984e+06  1.978946e+06     47     238921  66069
#
#                            stopname  objectid SERVICE_PERIOD  \
# 0        Santa Clara Transit Center         1        Weekday
# 1       San Jose Airport Terminal A         2        Weekday
# 2       San Jose Airport Terminal B         3        Weekday
# 3       1st & Metro @ Metro Station         4        Weekday
# 4             El Camino & Lafayette         5        Weekday
# ...                             ...       ...            ...
# 3246    Virginia & Virginia Station      3247        Weekday
# 3247  Stokes & Southwest Expressway      3248        Weekday
# 3248            San Felipe & Bowery      3249        Weekday
# 3248            San Felipe & Bowery      3249        Weekday
# 3249              Bellew & McCarthy      3250        Weekday
#
#                   MAIN_CROSS_STREET ROUTES_SERVED  AVG_BOARDINGS  \
# 0        SANTA CLARA TRANSIT CENTER            22     152.880022
# 1     SAN JOSE AIRPORT - TERMINAL A            60     106.410278
# 2     SAN JOSE AIRPORT - TERMINAL B            60     101.895229
# 3                       1ST + METRO            60      99.060686
# 4             EL CAMINO + LAFAYETTE    22, 59, 60      40.890986
# ...                             ...           ...            ...
# 3246    VIRGINIA + VIRGINIA STATION           201       0.333333
# 3247       STOKES + SOUTHWEST EXPWY           202       0.000000
# 3248            SAN FELIPE + BOWERY        31, 39       1.279642
# 3248            SAN FELIPE + BOWERY        31, 39       1.279642
# 3249              Bellew + McCarthy            44       5.926389
#
#       AVG_ALIGHTINGS  AVG_ACTIVITY                         geometry
# 0         110.852250    263.732272   POINT (6144099.628 1954225.52)
# 1          97.183657    203.593936  POINT (6146822.451 1959780.783)
# 2          69.917892    171.813122  POINT (6148114.706 1958314.711)
# 3          57.995466    157.056152  POINT (6150233.012 1960218.742)
# 4          57.438087     98.329073  POINT (6141651.003 1954992.246)
# ...              ...           ...                              ...
# 3246        0.000000      0.333333  POINT (6157411.327 1941969.795)
# 3247        0.357143      0.357143  POINT (6146206.479 1935440.473)
# 3248        0.336508      1.616150  POINT (6190773.704 1935477.602)
# 3248        0.336508      1.616150  POINT (6190773.704 1935477.602)
# 3249        7.870670     13.797059  POINT (6148983.754 1978945.706)
#
# [4295 rows x 14 columns]

# %%
#remove unnecessary columns
cols = [
    "routes",
    "linedirid",
    "rtid", 
    "stopname", 
    "AVG_BOARDINGS", 
    "AVG_ALIGHTINGS",
    "AVG_ACTIVITY",
    "geometry"
]

ridership_gdf = station_ridership_gdf[cols].copy()

ridership_gdf = ridership_gdf.rename(columns={
    "routes": "route_name",
    "linedirid": "route_direction_id",
    "rtid": "stop_id",
    "stopname": "stop_name",
    "AVG_BOARDINGS": "boardings",
    "AVG_ALIGHTINGS": "alightings",
    "AVG_ACTIVITY": "total_b_a"
})

ridership_gdf
# Out:
#      route_name  route_direction_id  stop_id                      stop_name  \
# 0            22              238750    60001     Santa Clara Transit Center
# 1            60              239040    60008    San Jose Airport Terminal A
# 2            60              239041    60011    San Jose Airport Terminal B
# 3            60              239041    60014    1st & Metro @ Metro Station
# 4            22              238750    60020          El Camino & Lafayette
# ...         ...                 ...      ...                            ...
# 3246        201              238710    66066    Virginia & Virginia Station
# 3247        202              238720    66067  Stokes & Southwest Expressway
# 3248         31              238870    66068            San Felipe & Bowery
# 3248         39              238870    66068            San Felipe & Bowery
# 3249         47              238921    66069              Bellew & McCarthy
#
#        boardings  alightings   total_b_a                         geometry
# 0     152.880022  110.852250  263.732272   POINT (6144099.628 1954225.52)
# 1     106.410278   97.183657  203.593936  POINT (6146822.451 1959780.783)
# 2     101.895229   69.917892  171.813122  POINT (6148114.706 1958314.711)
# 3      99.060686   57.995466  157.056152  POINT (6150233.012 1960218.742)
# 4      40.890986   57.438087   98.329073  POINT (6141651.003 1954992.246)
# ...          ...         ...         ...                              ...
# 3246    0.333333    0.000000    0.333333  POINT (6157411.327 1941969.795)
# 3247    0.000000    0.357143    0.357143  POINT (6146206.479 1935440.473)
# 3248    1.279642    0.336508    1.616150  POINT (6190773.704 1935477.602)
# 3248    1.279642    0.336508    1.616150  POINT (6190773.704 1935477.602)
# 3249    5.926389    7.870670   13.797059  POINT (6148983.754 1978945.706)
#
# [4295 rows x 8 columns]

# %%
#select routes 22, 522, 23, 523, 25, and 60
selected_ridership_gdf = ridership_gdf[ridership_gdf['route_name'].isin(selected_routes)]
selected_ridership_gdf
# Out:
#      route_name  route_direction_id  stop_id                    stop_name  \
# 0            22              238750    60001   Santa Clara Transit Center
# 1            60              239040    60008  San Jose Airport Terminal A
# 2            60              239041    60011  San Jose Airport Terminal B
# 3            60              239041    60014  1st & Metro @ Metro Station
# 4            22              238750    60020        El Camino & Lafayette
# ...         ...                 ...      ...                          ...
# 3219         23              238761    66001        San Carlos & Meridian
# 3219        523              238761    66001        San Carlos & Meridian
# 3221         60              239040    66019  San Jose Airport Terminal B
# 3225         25              238790    66033               Clove & Ginger
# 3239         25              238790    66055             Moorpark & Empey
#
#        boardings  alightings   total_b_a                         geometry
# 0     152.880022  110.852250  263.732272   POINT (6144099.628 1954225.52)
# 1     106.410278   97.183657  203.593936  POINT (6146822.451 1959780.783)
# 2     101.895229   69.917892  171.813122  POINT (6148114.706 1958314.711)
# 3      99.060686   57.995466  157.056152  POINT (6150233.012 1960218.742)
# 4      40.890986   57.438087   98.329073  POINT (6141651.003 1954992.246)
# ...          ...         ...         ...                              ...
# 3219  156.296391  174.049290  330.345680  POINT (6150710.015 1943405.861)
# 3219  156.296391  174.049290  330.345680  POINT (6150710.015 1943405.861)
# 3221  105.515644   69.771954  175.287597  POINT (6148161.172 1958273.948)
# 3225   37.628251   52.159478   89.787729   POINT (6143691.14 1939440.166)
# 3239   18.094340   27.458611   45.552951  POINT (6143692.336 1940729.953)
#
# [654 rows x 8 columns]

# %%
selected_ridership_gdf.plot()
# Out:
# <Axes: >

# %%
#save in separate folder
selected_routes_gdf.to_csv('../02-data/processed/selected_routes.csv')
selected_ridership_gdf.to_csv('../02-data/processed/selected_station_ridership.csv')

# %%
#Source: https://gisdata-csj.opendata.arcgis.com/datasets/CSJ::average-daily-traffic/explore?location=37.332044%2C-121.880204%2C10
adt_df = pd.read_csv('../02-data/raw/Average_Daily_Traffic.csv')
adt_gdf_geometry = [Point(xy) for xy in zip(adt_df["X"], adt_df["Y"])]

adt_gdf = gpd.GeoDataFrame(adt_df, geometry=adt_gdf_geometry, crs="EPSG:2227")
adt_gdf = adt_gdf.to_crs("EPSG:2227")
adt_gdf
# Out:
#                  X             Y  OBJECTID  FACILITYID  INTID   LATITUDE  \
# 0     6.159659e+06  1.952402e+06      4446        2045   2045  37.348694
# 1     6.165294e+06  1.938841e+06      4447        2046   2046  37.311681
# 2     6.158495e+06  1.951732e+06      4448        2047   2047  37.346808
# 3     6.158545e+06  1.951646e+06      4449        2048   2048  37.346572
# 4     6.148940e+06  1.958002e+06      4450        2049   2049  37.363632
# ...            ...           ...       ...         ...    ...        ...
# 2394  6.169466e+06  1.956389e+06      7281        4473   4473  37.360029
# 2395  6.171081e+06  1.954917e+06      7282        4474   4474  37.356051
# 2396  6.164263e+06  1.950131e+06      7283        4475   4475  37.342634
# 2397  6.164839e+06  1.950568e+06      7284        4476   4476  37.343858
# 2398  6.163788e+06  1.949771e+06      7285        4477   4477  37.341627
#
#        LONGITUDE               COUNTDATE      ADT          STREETONE  ...  \
# 0    -121.883045  2018/03/27 00:00:00+00   5613.0            13TH ST  ...
# 1    -121.862988  2018/04/10 00:00:00+00   6265.0             7TH ST  ...
# 2    -121.887016  2018/07/31 00:00:00+00   1043.0             9TH ST  ...
# 3    -121.886841  2018/07/31 00:00:00+00   1207.0             9TH ST  ...
# 4    -121.920211  2018/08/22 00:00:00+00  14432.0       AIRPORT BLVD  ...
# ...          ...                     ...      ...                ...  ...
# 2394 -121.849505  2021/12/02 00:00:00+00   3994.0  Jose Figueres Ave  ...
# 2395 -121.843873  2021/12/02 00:00:00+00   1207.0        Scharff Ave  ...
# 2396 -121.867090  2021/12/02 00:00:00+00   3068.0     San Antonio St  ...
# 2397 -121.865132  2021/12/02 00:00:00+00   4238.0     San Antonio St  ...
# 2398 -121.868703  2021/12/02 00:00:00+00   2395.0     San Antonio St  ...
#
#             STREETTWO TRAVELDIRE                           NEARINTERS  \
# 0       WASHINGTON ST        N/S              13TH ST & WASHINGTON ST
# 1             LEO AVE        N/S                     7TH ST & LEO AVE
# 2       WASHINGTON ST        N/S               9TH ST & WASHINGTON ST
# 3       WASHINGTON ST        N/S               9TH ST & WASHINGTON ST
# 4          SKYPORT DR    One Way            AIRPORT BLVD & SKYPORT DR
# ...               ...        ...                                  ...
# 2394  Rio Guacimal Ct        N/S  Jose Figueres Ave & Rio Guacimal Ct
# 2395      Lausett Ave        N/S            Scharff Ave & Lausett Ave
# 2396          21st St        E/W             San Antonio St & 21st St
# 2397          23rd St        E/W             San Antonio St & 23rd St
# 2398          19th St        E/W             San Antonio St & 19th St
#
#           CITY  ADTONE  ADTTWO  CREATIONDATE              LASTUPDATE NOTES  \
# 0     San Jose  2339.0  3274.0           NaN  2021/03/18 17:05:47+00
# 1     San Jose  2842.0  3423.0           NaN  2021/03/18 17:05:47+00
# 2     San Jose   589.0   454.0           NaN  2021/03/18 17:05:47+00
# 3     San Jose   740.0   467.0           NaN  2021/03/18 17:05:47+00
# 4     San Jose     NaN     NaN           NaN  2021/03/18 17:05:47+00
# ...        ...     ...     ...           ...                     ...   ...
# 2394  San Jose  1983.0  2011.0           NaN  2022/04/14 20:14:37+00   NaN
# 2395  San Jose   656.0   551.0           NaN  2022/04/14 20:14:37+00   NaN
# 2396  San Jose  1521.0  1547.0           NaN  2022/04/14 20:14:37+00   NaN
# 2397  San Jose  2305.0  1933.0           NaN  2022/04/14 20:14:37+00   NaN
# 2398  San Jose  1156.0  1239.0           NaN  2022/04/14 20:14:37+00   NaN
#
#                              geometry
# 0     POINT (6159659.425 1952401.843)
# 1     POINT (6165293.598 1938841.482)
# 2     POINT (6158494.955 1951732.473)
# 3     POINT (6158544.746 1951645.735)
# 4     POINT (6148939.759 1958001.956)
# ...                               ...
# 2394   POINT (6169465.578 1956389.19)
# 2395  POINT (6171081.379 1954917.494)
# 2396  POINT (6164262.808 1950130.677)
# 2397  POINT (6164838.516 1950567.683)
# 2398  POINT (6163788.484 1949770.831)
#
# [2399 rows x 21 columns]

# %%
cols = [
    "OBJECTID",
    "ADT",
    "STREETONE", 
    "DIRECTION", 
    "STREETTWO", 
    "NEARINTERS",
    "geometry"
]

sj_adt_gdf = adt_gdf[cols].copy()

sj_adt_gdf = sj_adt_gdf.rename(columns={
    "OBJECTID" : "counter_id",
    "ADT" : "adt",
    "STREETONE" : "main_road", 
    "DIRECTION" : "counter_location", 
    "STREETTWO" : "cross_road", 
    "NEARINTERS" : "nearby_intersect"
})

sj_adt_gdf.dropna()
sj_adt_gdf['main_road'] = [item.upper() for item in sj_adt_gdf['main_road']]
sj_adt_gdf['cross_road'] = [item.upper() for item in sj_adt_gdf['cross_road']]
sj_adt_gdf['nearby_intersect'] = [item.upper() for item in sj_adt_gdf['nearby_intersect']]
sj_adt_gdf
# Out:
#       counter_id      adt          main_road counter_location  \
# 0           4446   5613.0            13TH ST             N of
# 1           4447   6265.0             7TH ST             S of
# 2           4448   1043.0             9TH ST             N of
# 3           4449   1207.0             9TH ST             S of
# 4           4450  14432.0       AIRPORT BLVD             S of
# ...          ...      ...                ...              ...
# 2394        7281   3994.0  JOSE FIGUERES AVE             S of
# 2395        7282   1207.0        SCHARFF AVE             N of
# 2396        7283   3068.0     SAN ANTONIO ST             E of
# 2397        7284   4238.0     SAN ANTONIO ST             E of
# 2398        7285   2395.0     SAN ANTONIO ST             E of
#
#            cross_road                     nearby_intersect  \
# 0       WASHINGTON ST              13TH ST & WASHINGTON ST
# 1             LEO AVE                     7TH ST & LEO AVE
# 2       WASHINGTON ST               9TH ST & WASHINGTON ST
# 3       WASHINGTON ST               9TH ST & WASHINGTON ST
# 4          SKYPORT DR            AIRPORT BLVD & SKYPORT DR
# ...               ...                                  ...
# 2394  RIO GUACIMAL CT  JOSE FIGUERES AVE & RIO GUACIMAL CT
# 2395      LAUSETT AVE            SCHARFF AVE & LAUSETT AVE
# 2396          21ST ST             SAN ANTONIO ST & 21ST ST
# 2397          23RD ST             SAN ANTONIO ST & 23RD ST
# 2398          19TH ST             SAN ANTONIO ST & 19TH ST
#
#                              geometry
# 0     POINT (6159659.425 1952401.843)
# 1     POINT (6165293.598 1938841.482)
# 2     POINT (6158494.955 1951732.473)
# 3     POINT (6158544.746 1951645.735)
# 4     POINT (6148939.759 1958001.956)
# ...                               ...
# 2394   POINT (6169465.578 1956389.19)
# 2395  POINT (6171081.379 1954917.494)
# 2396  POINT (6164262.808 1950130.677)
# 2397  POINT (6164838.516 1950567.683)
# 2398  POINT (6163788.484 1949770.831)
#
# [2399 rows x 7 columns]

# %%
#create a buffer around the selected routes, then select all traffic counters within the buffer
route_buffers = selected_routes_gdf.copy()
route_buffers['geometry'] = route_buffers['geometry'].buffer(250)
route_buffers
# Out:
#     route_id route_name                         route_desc  category  \
# 2      23875         22              PALO ALTO - EASTRIDGE  Frequent
# 3      23876         23        DE ANZA COL - ALUM ROCK STN  Frequent
# 4      23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 20     23904         60     WINCHESTER STN - MILPITAS BART  Frequent
# 54     23896        522              PALO ALTO - EASTRIDGE     Rapid
# 55     23897        523   SAN JOSE STATE - LOCKHEED MARTIN     Rapid
#
#      route_length  object_id  \
# 2   242559.907697          3
# 3   120202.952188          4
# 4   140850.289491          5
# 20  151256.059019         21
# 54  253522.042435         55
# 55  162676.690292         56
#
#                                              geometry
# 2   POLYGON ((6077534.618 1988551.218, 6077534.591...
# 3   POLYGON ((6111857.309 1943710.691, 6111857.38 ...
# 4   POLYGON ((6113146.198 1941141.056, 6113146.078...
# 20  POLYGON ((6139345.747 1950518.707, 6139345.608...
# 54  POLYGON ((6077534.618 1988551.218, 6077534.591...
# 55  POLYGON ((6113181.487 1943682.679, 6113181.4 1...

# %%
selected_sj_adt = gpd.sjoin(sj_adt_gdf, route_buffers, how="inner", predicate="within")
selected_sj_adt
# Out:
#       counter_id      adt     main_road counter_location      cross_road  \
# 4           4450  14432.0  AIRPORT BLVD             S of      SKYPORT DR
# 11          4457   8385.0   ALMADEN AVE             N of       WILLOW ST
# 23          4469    848.0   BLEWETT AVE             S of       WILLOW ST
# 24          4470    936.0  BLEWETTE AVE             S of       WILLOW ST
# 28          4474  45690.0     BROKAW RD             E of      OAKLAND RD
# ...          ...      ...           ...              ...             ...
# 2364        7251  13221.0       KING RD             S of       OCALA AVE
# 2374        7261  18169.0      STORY RD             E of  BAL HARBOR WAY
# 2375        7262  20206.0      STORY RD             E of     JACKSON AVE
# 2376        7263  21056.0      STORY RD             W of     ROBERTS AVE
# 2377        7264  30501.0      STORY RD             W of     VIA FERRARI
#
#                nearby_intersect                         geometry  index_right  \
# 4     AIRPORT BLVD & SKYPORT DR  POINT (6148939.759 1958001.956)           20
# 11      ALMADEN AVE & WILLOW ST  POINT (6159716.967 1941603.893)            4
# 23      BLEWETT AVE & WILLOW ST  POINT (6154536.488 1937960.998)            4
# 24     BLEWETTE AVE & WILLOW ST  POINT (6154536.488 1937960.998)            4
# 28         BROKAW RD&OAKLAND RD   POINT (6156171.62 1964851.784)           20
# ...                         ...                              ...          ...
# 2364        KING RD & OCALA AVE  POINT (6173723.992 1945717.512)            2
# 2374  STORY RD & BAL HARBOR WAY   POINT (6172131.01 1949785.076)            4
# 2375     STORY RD & JACKSON AVE  POINT (6174397.292 1951653.894)            4
# 2376     STORY RD & ROBERTS AVE  POINT (6166346.746 1945014.702)            4
# 2377     STORY RD & VIA FERRARI  POINT (6168690.093 1946933.034)            4
#
#       route_id route_name                         route_desc  category  \
# 4        23904         60     WINCHESTER STN - MILPITAS BART  Frequent
# 11       23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 23       23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 24       23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 28       23904         60     WINCHESTER STN - MILPITAS BART  Frequent
# ...        ...        ...                                ...       ...
# 2364     23875         22              PALO ALTO - EASTRIDGE  Frequent
# 2374     23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 2375     23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 2376     23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
# 2377     23879         25  DE ANZA COL - VMC - ALUM ROCK STN  Frequent
#
#        route_length  object_id
# 4     151256.059019         21
# 11    140850.289491          5
# 23    140850.289491          5
# 24    140850.289491          5
# 28    151256.059019         21
# ...             ...        ...
# 2364  242559.907697          3
# 2374  140850.289491          5
# 2375  140850.289491          5
# 2376  140850.289491          5
# 2377  140850.289491          5
#
# [494 rows x 14 columns]

# %%
selected_sj_adt.plot()
# Out:
# <Axes: >

# %%
#average daily traffic for streets in San Jose that the selected bus routes run along
selected_sj_adt.to_csv("../02-data/processed/selected_sj_adt.csv")

# %%
# --- Vehicle positions: buffer filter to corridor (routes 22/522/23/523/25/60) ---

VEHICLE_CSV = "../02-data/processed/vehicle_route_location_speed_data_20260326_103149.csv"
OUT_CSV = "../02-data/processed/vehicle_points_filtered_buffer250ft.csv"
BUFFER_FT = 250  # EPSG:2227 feet (~76m)

# ensure routes are in EPSG:2227 (feet)
if selected_routes_gdf.crs is None or selected_routes_gdf.crs.to_string() != "EPSG:2227":
    selected_routes_gdf = selected_routes_gdf.to_crs("EPSG:2227")

# route corridor buffer
route_buffers = selected_routes_gdf.copy()
route_buffers["geometry"] = route_buffers.geometry.buffer(BUFFER_FT)

# load vehicle csv
veh = pd.read_csv(VEHICLE_CSV)
veh = veh.dropna(subset=["lat", "lon", "route_id", "time"])
veh["route_id"] = veh["route_id"].astype(str).str.strip()

veh_gdf = gpd.GeoDataFrame(
    veh,
    geometry=gpd.points_from_xy(veh["lon"], veh["lat"]),
    crs="EPSG:4326"
).to_crs("EPSG:2227")

veh_in = gpd.sjoin(
    veh_gdf,
    route_buffers[["route_name", "geometry"]],
    how="inner",
    predicate="within"
)

veh_in = veh_in.drop_duplicates(subset=["bus_id", "trip_id", "time", "route_id"])


print("veh_gdf rows:", len(veh_gdf))
print("veh_in rows :", len(veh_in))
print("kept %:", round(len(veh_in) / len(veh_gdf), 3))
# Out:
# veh_gdf rows: 82115
# veh_in rows : 80834
# kept %: 0.984

# %%
# --- Summary stats for midterm (counts before/after by route_id) ---
before_counts = veh_gdf.groupby("route_id").size().rename("before_n").reset_index()
after_counts  = veh_in.groupby("route_id").size().rename("after_n").reset_index()

counts = before_counts.merge(after_counts, on="route_id", how="left").fillna({"after_n": 0})
counts["after_n"] = counts["after_n"].astype(int)
counts["kept_pct"] = (counts["after_n"] / counts["before_n"]).round(3)

display(counts.sort_values("route_id"))

# save filtered output
veh_in_out = veh_in.drop(columns=[c for c in ["index_right"] if c in veh_in.columns])
veh_in_out.to_csv(OUT_CSV, index=False)
print("Saved:", OUT_CSV)
# Out:
#     route_id  before_n  after_n  kept_pct
# 0         22     19313    18946     0.981
# 1         23     11749    11504     0.979
# 2         25     14307    14140     0.988
# 3         60     12318    12163     0.987
# 4  Rapid 522     15920    15707     0.987
# 5  Rapid 523      8508     8374     0.984
# Saved: ../02-data/processed/vehicle_points_filtered_buffer250ft.csv

# %%
# Load GTFS static data
routes = pd.read_csv("../02-data/raw/Static_routes.txt")
trips = pd.read_csv("../02-data/raw/Static_trips.txt")
stop_times = pd.read_csv("../02-data/raw/Static_stop_times.txt")
stops = pd.read_csv("../02-data/raw/Static_stops.txt")

# Load GTFS-Realtime TripUpdates
tripupdates = pd.read_csv("../02-data/raw/tripupdates_20260326.csv")

# %%
# Ensure consistent data types
tripupdates["trip_id"] = tripupdates["trip_id"].astype(str)
stop_times["trip_id"] = stop_times["trip_id"].astype(str)
trips["trip_id"] = trips["trip_id"].astype(str)

tripupdates["stop_id"] = tripupdates["stop_id"].astype(str)
stop_times["stop_id"] = stop_times["stop_id"].astype(str)
stops["stop_id"] = stops["stop_id"].astype(str)

tripupdates["stop_sequence"] = tripupdates["stop_sequence"].astype(int)
stop_times["stop_sequence"] = stop_times["stop_sequence"].astype(int)

# %%
# Merge realtime and scheduled data
merged = tripupdates.merge(
    stop_times[["trip_id", "stop_sequence", "arrival_time"]],
    on=["trip_id", "stop_sequence"],
    how="left"
)

# %%
# Convert scheduled arrival time to seconds
def time_to_seconds(t):
    if pd.isna(t):
        return None
    h, m, s = map(int, t.split(":"))
    return h * 3600 + m * 60 + s

merged["scheduled_arrival_sec"] = merged["arrival_time"].apply(time_to_seconds)

# %%
# Convert actual arrival time to local time
merged["actual_arrival_time"] = pd.to_datetime(
    merged["arr_time"], unit="s", utc=True
).dt.tz_convert("America/Los_Angeles")

merged["actual_arrival_sec"] = (
    merged["actual_arrival_time"].dt.hour * 3600 +
    merged["actual_arrival_time"].dt.minute * 60 +
    merged["actual_arrival_time"].dt.second
)

# %%
# Compute delay
merged["computed_delay_sec"] = (
    merged["actual_arrival_sec"] - merged["scheduled_arrival_sec"]
)

# %%
# Adjust for trips crossing midnight
merged.loc[merged["computed_delay_sec"] < -12 * 3600, "computed_delay_sec"] += 24 * 3600

# %%
# Merge route and stop information
merged = merged.merge(trips[["trip_id", "route_id"]], on="trip_id", how="left")
merged = merged.merge(stops[["stop_id", "stop_name"]], on="stop_id", how="left")

# %%
# Remove invalid records
cleaned_data = merged.dropna(subset=["computed_delay_sec"])

# %%
cleaned_data["computed_delay_sec"].describe()
# Out:
# count    3281.000000
# mean      -53.654678
# std       176.821861
# min      -921.000000
# 25%      -125.000000
# 50%       -63.000000
# 75%        -6.000000
# max      1030.000000
# Name: computed_delay_sec, dtype: float64

# %%
# Save cleaned dataset
cleaned_data.to_csv("../02-data/processed/cleaned_delay_data.csv", index=False)

print("Cleaned data saved to data/processed/cleaned_delay_data.csv")
# Out:
# Cleaned data saved to data/processed/cleaned_delay_data.csv
